# %%
from __future__ import print_function, division

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

import thinkstats2_mod
import thinkplot

import statsmodels.formula.api as smf

# %%
dct = thinkstats2_mod.ReadStataDct('GSS/GSS.dct')
df = dct.ReadFixedWidth('GSS/GSS.dat')
display(df.shape)
# display(df)
# Out:
# (62466, 182)

# %%
# Filter out years without relevant data
df = df[df.year >= 1974]
display(df.shape)

# Filter out invalid polviews
# df = df[df.polviews > 0]
df = df[df.polviews <= 7]
display(df.shape)

# Filter out invalid age respondants
df = df[df.age <= 89]
display(df.shape)

# Filter out work status no answers
df = df[df.wrkstat != 9]
display(df.shape)

# Filter out marital status no answers
df = df[df.marital != 9]
display(df.shape)

# Filter out years of education w/ don't know, no answer
df = df[df.educ <= 20]
display(df.shape)

# Filter out degree of education invalid
df = df[df.degree <= 4]
display(df.shape)

# Filter out perceived class invalid
df = df[df.class_ > 0]
df = df[df.class_ <= 4]
display(df.shape)

# Filter out total fam income invalid
df = df[df.income > 0]
df = df[df.income <= 12]
display(df.shape)

df_control = df.copy(deep=True)

# display(df)
# Out:
# (59349, 182)
# (56741, 182)
# (56562, 182)
# (56551, 182)
# (56542, 182)
# (56450, 182)
# (56395, 182)
# (53914, 182)
# (48881, 182)

# %%
formula = 'df_control.polviews ~ df_control.age + df_control.wrkstat + df_control.marital + df_control.educ + df_control.degree + df_control.class_ + df_control.income'
model = smf.mnlogit(formula, data=df)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.759130
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            MNLogit Regression Results
# ===============================================================================
# Dep. Variable:     df_control.polviews   No. Observations:                48881
# Model:                         MNLogit   Df Residuals:                    48825
# Method:                            MLE   Df Model:                           49
# Date:                 Wed, 19 Apr 2017   Pseudo R-squ.:                 0.01729
# Time:                         23:51:39   Log-Likelihood:                -85988.
# converged:                        True   LL-Null:                       -87501.
#                                          LLR p-value:                     0.000
# =========================================================================================
# df_control.polviews=1       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.3537      0.325      4.170      0.000       0.717       1.990
# df_control.age           -0.0035      0.002     -1.587      0.112      -0.008       0.001
# df_control.wrkstat        0.0058      0.016      0.366      0.714      -0.025       0.037
# df_control.marital        0.1490      0.022      6.910      0.000       0.107       0.191
# df_control.educ          -0.0807      0.023     -3.433      0.001      -0.127      -0.035
# df_control.degree         0.2634      0.057      4.602      0.000       0.151       0.376
# df_control.class_        -0.0005      0.055     -0.009      0.993      -0.108       0.107
# df_control.income        -0.1495      0.015    -10.220      0.000      -0.178      -0.121
# -----------------------------------------------------------------------------------------
# df_control.polviews=2       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.7398      0.243     11.290      0.000       2.264       3.215
# df_control.age           -0.0072      0.002     -4.466      0.000      -0.010      -0.004
# df_control.wrkstat       -0.0194      0.011     -1.705      0.088      -0.042       0.003
# df_control.marital        0.0540      0.016      3.485      0.000       0.024       0.084
# df_control.educ          -0.0539      0.017     -3.091      0.002      -0.088      -0.020
# df_control.degree         0.2337      0.041      5.634      0.000       0.152       0.315
# df_control.class_         0.0817      0.040      2.028      0.043       0.003       0.161
# df_control.income        -0.1503      0.012    -12.733      0.000      -0.173      -0.127
# -----------------------------------------------------------------------------------------
# df_control.polviews=3       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 3.5012      0.239     14.659      0.000       3.033       3.969
# df_control.age           -0.0123      0.002     -7.702      0.000      -0.015      -0.009
# df_control.wrkstat       -0.0274      0.011     -2.452      0.014      -0.049      -0.006
# df_control.marital       -0.0307      0.015     -2.002      0.045      -0.061      -0.001
# df_control.educ          -0.0642      0.017     -3.747      0.000      -0.098      -0.031
# df_control.degree         0.1483      0.041      3.617      0.000       0.068       0.229
# df_control.class_         0.0736      0.040      1.849      0.064      -0.004       0.152
# df_control.income        -0.1420      0.012    -12.097      0.000      -0.165      -0.119
# -----------------------------------------------------------------------------------------
# df_control.polviews=4       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.6221      0.217     21.310      0.000       4.197       5.047
# df_control.age           -0.0035      0.001     -2.473      0.013      -0.006      -0.001
# df_control.wrkstat       -0.0108      0.010     -1.083      0.279      -0.030       0.009
# df_control.marital       -0.0723      0.014     -5.192      0.000      -0.100      -0.045
# df_control.educ          -0.0836      0.015     -5.425      0.000      -0.114      -0.053
# df_control.degree        -0.0545      0.037     -1.474      0.140      -0.127       0.018
# df_control.class_        -0.0440      0.036     -1.226      0.220      -0.114       0.026
# df_control.income        -0.0987      0.011     -8.976      0.000      -0.120      -0.077
# -----------------------------------------------------------------------------------------
# df_control.polviews=5       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 3.1752      0.233     13.625      0.000       2.718       3.632
# df_control.age           -0.0035      0.002     -2.294      0.022      -0.007      -0.001
# df_control.wrkstat       -0.0400      0.011     -3.669      0.000      -0.061      -0.019
# df_control.marital       -0.1307      0.015     -8.606      0.000      -0.160      -0.101
# df_control.educ          -0.0715      0.017     -4.294      0.000      -0.104      -0.039
# df_control.degree         0.1325      0.040      3.332      0.001       0.055       0.211
# df_control.class_         0.1465      0.039      3.766      0.000       0.070       0.223
# df_control.income        -0.1067      0.012     -9.097      0.000      -0.130      -0.084
# -----------------------------------------------------------------------------------------
# df_control.polviews=6       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.4205      0.235     10.300      0.000       1.960       2.881
# df_control.age            0.0059      0.002      3.817      0.000       0.003       0.009
# df_control.wrkstat       -0.0089      0.011     -0.812      0.417      -0.030       0.013
# df_control.marital       -0.1578      0.016    -10.052      0.000      -0.189      -0.127
# df_control.educ          -0.0725      0.017     -4.324      0.000      -0.105      -0.040
# df_control.degree         0.0903      0.040      2.242      0.025       0.011       0.169
# df_control.class_         0.1712      0.039      4.343      0.000       0.094       0.248
# df_control.income        -0.0885      0.012     -7.437      0.000      -0.112      -0.065
# -----------------------------------------------------------------------------------------
# df_control.polviews=7       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.8839      0.306      6.158      0.000       1.284       2.484
# df_control.age            0.0086      0.002      3.965      0.000       0.004       0.013
# df_control.wrkstat       -0.0220      0.016     -1.413      0.158      -0.053       0.009
# df_control.marital       -0.1154      0.023     -4.976      0.000      -0.161      -0.070
# df_control.educ          -0.1188      0.022     -5.466      0.000      -0.161      -0.076
# df_control.degree         0.0319      0.057      0.562      0.574      -0.079       0.143
# df_control.class_         0.1132      0.055      2.064      0.039       0.006       0.221
# df_control.income        -0.1267      0.015     -8.462      0.000      -0.156      -0.097
# =========================================================================================
# """

# %%
df_1974 = df_control.copy(deep=True)

# Select 1974
df_1974 = df_1974[df_1974.year == 1974]
display(df_1974.shape)
# Out:
# (1294, 182)

# %%
formula = 'df_1974.polviews ~ df_1974.age + df_1974.wrkstat + df_1974.marital + df_1974.educ + df_1974.degree + df_1974.class_ + df_1974.income'
model = smf.mnlogit(formula, data=df_1974)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.573435
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:       df_1974.polviews   No. Observations:                 1294
# Model:                        MNLogit   Df Residuals:                     1246
# Method:                           MLE   Df Model:                           42
# Date:                Wed, 19 Apr 2017   Pseudo R-squ.:                 0.02766
# Time:                        23:51:39   Log-Likelihood:                -2036.0
# converged:                       True   LL-Null:                       -2094.0
#                                         LLR p-value:                 7.805e-09
# ======================================================================================
# df_1974.polviews=2       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              4.8165      1.904      2.529      0.011       1.084       8.549
# df_1974.age           -0.0267      0.015     -1.823      0.068      -0.055       0.002
# df_1974.wrkstat        0.1120      0.108      1.036      0.300      -0.100       0.324
# df_1974.marital       -0.3523      0.144     -2.453      0.014      -0.634      -0.071
# df_1974.educ          -0.1281      0.139     -0.925      0.355      -0.400       0.144
# df_1974.degree         0.2827      0.357      0.791      0.429      -0.418       0.983
# df_1974.class_         0.0878      0.373      0.236      0.814      -0.643       0.819
# df_1974.income        -0.0002      0.079     -0.002      0.998      -0.154       0.154
# --------------------------------------------------------------------------------------
# df_1974.polviews=3       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              3.3932      1.907      1.779      0.075      -0.345       7.132
# df_1974.age           -0.0181      0.015     -1.244      0.214      -0.047       0.010
# df_1974.wrkstat        0.1465      0.108      1.357      0.175      -0.065       0.358
# df_1974.marital       -0.3672      0.144     -2.546      0.011      -0.650      -0.085
# df_1974.educ          -0.0753      0.139     -0.542      0.588      -0.347       0.197
# df_1974.degree         0.1309      0.358      0.366      0.714      -0.570       0.832
# df_1974.class_         0.1620      0.374      0.433      0.665      -0.570       0.894
# df_1974.income         0.0459      0.079      0.580      0.562      -0.109       0.201
# --------------------------------------------------------------------------------------
# df_1974.polviews=4       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              4.4530      1.844      2.415      0.016       0.840       8.066
# df_1974.age           -0.0111      0.014     -0.786      0.432      -0.039       0.017
# df_1974.wrkstat        0.1617      0.105      1.533      0.125      -0.045       0.368
# df_1974.marital       -0.4492      0.139     -3.224      0.001      -0.722      -0.176
# df_1974.educ          -0.0612      0.134     -0.458      0.647      -0.323       0.201
# df_1974.degree        -0.1535      0.347     -0.443      0.658      -0.833       0.526
# df_1974.class_         0.0215      0.362      0.059      0.953      -0.687       0.730
# df_1974.income         0.0720      0.076      0.942      0.346      -0.078       0.222
# --------------------------------------------------------------------------------------
# df_1974.polviews=5       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              3.2841      1.908      1.721      0.085      -0.456       7.024
# df_1974.age           -0.0047      0.015     -0.320      0.749      -0.033       0.024
# df_1974.wrkstat        0.1134      0.108      1.049      0.294      -0.098       0.325
# df_1974.marital       -0.5533      0.149     -3.717      0.000      -0.845      -0.262
# df_1974.educ          -0.0950      0.139     -0.684      0.494      -0.367       0.177
# df_1974.degree         0.2490      0.358      0.696      0.486      -0.452       0.950
# df_1974.class_         0.1177      0.376      0.313      0.754      -0.619       0.854
# df_1974.income         0.0745      0.080      0.931      0.352      -0.082       0.231
# --------------------------------------------------------------------------------------
# df_1974.polviews=6       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.7148      1.940      0.884      0.377      -2.087       5.517
# df_1974.age            0.0116      0.015      0.782      0.434      -0.017       0.041
# df_1974.wrkstat        0.1223      0.110      1.113      0.266      -0.093       0.338
# df_1974.marital       -0.4785      0.154     -3.115      0.002      -0.780      -0.177
# df_1974.educ          -0.0178      0.141     -0.127      0.899      -0.294       0.258
# df_1974.degree         0.0043      0.365      0.012      0.991      -0.712       0.720
# df_1974.class_         0.0327      0.383      0.085      0.932      -0.718       0.783
# df_1974.income         0.0576      0.082      0.705      0.481      -0.103       0.218
# --------------------------------------------------------------------------------------
# df_1974.polviews=7       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.0058      2.326      0.862      0.389      -2.554       6.566
# df_1974.age            0.0022      0.018      0.120      0.904      -0.033       0.038
# df_1974.wrkstat        0.0701      0.131      0.536      0.592      -0.186       0.326
# df_1974.marital       -0.6276      0.229     -2.743      0.006      -1.076      -0.179
# df_1974.educ          -0.0670      0.169     -0.397      0.691      -0.398       0.264
# df_1974.degree        -0.1083      0.470     -0.231      0.818      -1.029       0.812
# df_1974.class_         0.1415      0.468      0.303      0.762      -0.775       1.058
# df_1974.income        -0.0194      0.103     -0.188      0.851      -0.222       0.183
# ======================================================================================
# """

# %%
df_2016 = df_control.copy(deep=True)

# Select 2016
df_2016 = df_2016[df_2016.year == 2016]
display(df_2016.shape)
# Out:
# (2337, 182)

# %%
formula = 'df_2016.polviews ~ df_2016.age + df_2016.wrkstat + df_2016.marital + df_2016.educ + df_2016.degree + df_2016.class_ + df_2016.income'
model = smf.mnlogit(formula, data=df_2016)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.670273
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:       df_2016.polviews   No. Observations:                 2337
# Model:                        MNLogit   Df Residuals:                     2289
# Method:                           MLE   Df Model:                           42
# Date:                Wed, 19 Apr 2017   Pseudo R-squ.:                 0.02417
# Time:                        23:51:39   Log-Likelihood:                -3903.4
# converged:                       True   LL-Null:                       -4000.1
#                                         LLR p-value:                 2.688e-21
# ======================================================================================
# df_2016.polviews=2       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.0569      1.147      0.921      0.357      -1.191       3.305
# df_2016.age           -0.0040      0.007     -0.537      0.591      -0.018       0.010
# df_2016.wrkstat        0.0454      0.055      0.832      0.405      -0.061       0.152
# df_2016.marital       -0.0314      0.072     -0.437      0.662      -0.172       0.109
# df_2016.educ           0.0014      0.083      0.017      0.986      -0.161       0.164
# df_2016.degree         0.1465      0.190      0.769      0.442      -0.227       0.520
# df_2016.class_        -0.3394      0.179     -1.892      0.059      -0.691       0.012
# df_2016.income         0.0526      0.048      1.103      0.270      -0.041       0.146
# --------------------------------------------------------------------------------------
# df_2016.polviews=3       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.0178      1.180      0.863      0.388      -1.295       3.330
# df_2016.age           -0.0005      0.008     -0.061      0.951      -0.015       0.014
# df_2016.wrkstat       -0.0120      0.056     -0.213      0.831      -0.122       0.098
# df_2016.marital       -0.0709      0.074     -0.963      0.336      -0.215       0.073
# df_2016.educ           0.0038      0.084      0.045      0.964      -0.161       0.168
# df_2016.degree        -0.1101      0.195     -0.566      0.571      -0.491       0.271
# df_2016.class_        -0.3434      0.184     -1.863      0.062      -0.705       0.018
# df_2016.income         0.0946      0.051      1.844      0.065      -0.006       0.195
# --------------------------------------------------------------------------------------
# df_2016.polviews=4       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.7672      1.030      2.687      0.007       0.749       4.786
# df_2016.age            0.0033      0.007      0.487      0.626      -0.010       0.016
# df_2016.wrkstat       -0.0084      0.050     -0.168      0.867      -0.106       0.089
# df_2016.marital       -0.0377      0.066     -0.574      0.566      -0.166       0.091
# df_2016.educ          -0.0322      0.074     -0.432      0.665      -0.178       0.114
# df_2016.degree        -0.2596      0.173     -1.502      0.133      -0.598       0.079
# df_2016.class_        -0.2780      0.163     -1.710      0.087      -0.597       0.041
# df_2016.income         0.0759      0.042      1.803      0.071      -0.007       0.158
# --------------------------------------------------------------------------------------
# df_2016.polviews=5       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.5755      1.121      2.298      0.022       0.379       4.772
# df_2016.age            0.0079      0.007      1.078      0.281      -0.006       0.022
# df_2016.wrkstat       -0.0630      0.055     -1.145      0.252      -0.171       0.045
# df_2016.marital       -0.2275      0.072     -3.145      0.002      -0.369      -0.086
# df_2016.educ          -0.0414      0.081     -0.512      0.609      -0.200       0.117
# df_2016.degree        -0.1227      0.189     -0.649      0.516      -0.493       0.248
# df_2016.class_        -0.2549      0.179     -1.426      0.154      -0.605       0.095
# df_2016.income         0.0284      0.047      0.607      0.544      -0.063       0.120
# --------------------------------------------------------------------------------------
# df_2016.polviews=6       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.9390      1.117      1.735      0.083      -0.251       4.129
# df_2016.age            0.0145      0.007      1.996      0.046       0.000       0.029
# df_2016.wrkstat       -0.0228      0.054     -0.420      0.675      -0.129       0.084
# df_2016.marital       -0.2531      0.072     -3.492      0.000      -0.395      -0.111
# df_2016.educ          -0.0285      0.081     -0.354      0.724      -0.187       0.130
# df_2016.degree        -0.0941      0.188     -0.501      0.616      -0.462       0.274
# df_2016.class_        -0.2248      0.177     -1.269      0.204      -0.572       0.122
# df_2016.income         0.0288      0.047      0.615      0.539      -0.063       0.120
# --------------------------------------------------------------------------------------
# df_2016.polviews=7       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.1576      1.350      0.858      0.391      -1.488       3.803
# df_2016.age            0.0190      0.009      2.061      0.039       0.001       0.037
# df_2016.wrkstat       -0.0013      0.068     -0.020      0.984      -0.135       0.132
# df_2016.marital       -0.0570      0.094     -0.607      0.544      -0.241       0.127
# df_2016.educ          -0.1266      0.095     -1.333      0.182      -0.313       0.060
# df_2016.degree        -0.2629      0.243     -1.083      0.279      -0.739       0.213
# df_2016.class_        -0.1448      0.220     -0.659      0.510      -0.575       0.286
# df_2016.income         0.0343      0.057      0.597      0.550      -0.078       0.147
# ======================================================================================
# """

# %%
formula = 'df_control.polviews ~ df_control.age'
model = smf.mnlogit(formula, data=df_control)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.782779
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            MNLogit Regression Results
# ===============================================================================
# Dep. Variable:     df_control.polviews   No. Observations:                48881
# Model:                         MNLogit   Df Residuals:                    48867
# Method:                            MLE   Df Model:                            7
# Date:                 Wed, 19 Apr 2017   Pseudo R-squ.:                0.004075
# Time:                         23:51:40   Log-Likelihood:                -87144.
# converged:                        True   LL-Null:                       -87501.
#                                          LLR p-value:                9.926e-150
# =========================================================================================
# df_control.polviews=1       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.2913      0.095     -3.074      0.002      -0.477      -0.106
# df_control.age           -0.0073      0.002     -3.610      0.000      -0.011      -0.003
# -----------------------------------------------------------------------------------------
# df_control.polviews=2       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.1602      0.068     17.051      0.000       1.027       1.294
# df_control.age           -0.0086      0.001     -5.997      0.000      -0.011      -0.006
# -----------------------------------------------------------------------------------------
# df_control.polviews=3       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.3388      0.067     19.945      0.000       1.207       1.470
# df_control.age           -0.0107      0.001     -7.555      0.000      -0.013      -0.008
# -----------------------------------------------------------------------------------------
# df_control.polviews=4       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.9056      0.060     31.501      0.000       1.787       2.024
# df_control.age            0.0009      0.001      0.733      0.464      -0.002       0.003
# -----------------------------------------------------------------------------------------
# df_control.polviews=5       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.0515      0.065     16.057      0.000       0.923       1.180
# df_control.age            0.0007      0.001      0.511      0.609      -0.002       0.003
# -----------------------------------------------------------------------------------------
# df_control.polviews=6       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.4260      0.067      6.358      0.000       0.295       0.557
# df_control.age            0.0118      0.001      8.681      0.000       0.009       0.014
# -----------------------------------------------------------------------------------------
# df_control.polviews=7       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -1.3184      0.097    -13.535      0.000      -1.509      -1.127
# df_control.age            0.0156      0.002      8.191      0.000       0.012       0.019
# =========================================================================================
# """

# %%
formula = 'df_control.polviews ~ df_control.age + df_control.marital'
model = smf.mnlogit(formula, data=df_control)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.775452
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            MNLogit Regression Results
# ===============================================================================
# Dep. Variable:     df_control.polviews   No. Observations:                48881
# Model:                         MNLogit   Df Residuals:                    48860
# Method:                            MLE   Df Model:                           14
# Date:                 Wed, 19 Apr 2017   Pseudo R-squ.:                0.008169
# Time:                         23:51:41   Log-Likelihood:                -86786.
# converged:                        True   LL-Null:                       -87501.
#                                          LLR p-value:                7.149e-297
# =========================================================================================
# df_control.polviews=1       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -1.1288      0.130     -8.664      0.000      -1.384      -0.873
# df_control.age        -9.939e-05      0.002     -0.047      0.962      -0.004       0.004
# df_control.marital        0.1943      0.021      9.206      0.000       0.153       0.236
# -----------------------------------------------------------------------------------------
# df_control.polviews=2       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.7632      0.090      8.480      0.000       0.587       0.940
# df_control.age           -0.0051      0.001     -3.409      0.001      -0.008      -0.002
# df_control.marital        0.0954      0.015      6.276      0.000       0.066       0.125
# -----------------------------------------------------------------------------------------
# df_control.polviews=3       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.2987      0.088     14.755      0.000       1.126       1.471
# df_control.age           -0.0103      0.001     -6.920      0.000      -0.013      -0.007
# df_control.marital        0.0086      0.015      0.573      0.566      -0.021       0.038
# -----------------------------------------------------------------------------------------
# df_control.polviews=4       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.0529      0.079     26.054      0.000       1.898       2.207
# df_control.age           -0.0003      0.001     -0.192      0.848      -0.003       0.002
# df_control.marital       -0.0402      0.014     -2.954      0.003      -0.067      -0.014
# -----------------------------------------------------------------------------------------
# df_control.polviews=5       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.4283      0.085     16.836      0.000       1.262       1.595
# df_control.age           -0.0022      0.001     -1.577      0.115      -0.005       0.001
# df_control.marital       -0.1077      0.015     -7.233      0.000      -0.137      -0.079
# -----------------------------------------------------------------------------------------
# df_control.polviews=6       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.8892      0.086     10.326      0.000       0.720       1.058
# df_control.age            0.0085      0.001      5.986      0.000       0.006       0.011
# df_control.marital       -0.1411      0.015     -9.169      0.000      -0.171      -0.111
# -----------------------------------------------------------------------------------------
# df_control.polviews=7       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -1.0511      0.123     -8.533      0.000      -1.292      -0.810
# df_control.age            0.0136      0.002      6.877      0.000       0.010       0.017
# df_control.marital       -0.0779      0.022     -3.473      0.001      -0.122      -0.034
# =========================================================================================
# """

# %%
formula = 'df_control.polviews ~ df_control.marital'
model = smf.mnlogit(formula, data=df_control)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.779617
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            MNLogit Regression Results
# ===============================================================================
# Dep. Variable:     df_control.polviews   No. Observations:                48881
# Model:                         MNLogit   Df Residuals:                    48867
# Method:                            MLE   Df Model:                            7
# Date:                 Wed, 19 Apr 2017   Pseudo R-squ.:                0.005842
# Time:                         23:51:42   Log-Likelihood:                -86989.
# converged:                        True   LL-Null:                       -87501.
#                                          LLR p-value:                1.823e-216
# =========================================================================================
# df_control.polviews=1       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -1.1331      0.064    -17.754      0.000      -1.258      -1.008
# df_control.marital        0.1942      0.020      9.885      0.000       0.156       0.233
# -----------------------------------------------------------------------------------------
# df_control.polviews=2       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.4928      0.043     11.413      0.000       0.408       0.577
# df_control.marital        0.1132      0.014      7.871      0.000       0.085       0.141
# -----------------------------------------------------------------------------------------
# df_control.polviews=3       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.7672      0.042     18.247      0.000       0.685       0.850
# df_control.marital        0.0421      0.014      2.946      0.003       0.014       0.070
# -----------------------------------------------------------------------------------------
# df_control.polviews=4       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.0395      0.037     54.453      0.000       1.966       2.113
# df_control.marital       -0.0394      0.013     -3.043      0.002      -0.065      -0.014
# -----------------------------------------------------------------------------------------
# df_control.polviews=5       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.3118      0.040     32.562      0.000       1.233       1.391
# df_control.marital       -0.1010      0.014     -7.113      0.000      -0.129      -0.073
# -----------------------------------------------------------------------------------------
# df_control.polviews=6       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.3392      0.041     32.921      0.000       1.259       1.419
# df_control.marital       -0.1636      0.015    -11.171      0.000      -0.192      -0.135
# -----------------------------------------------------------------------------------------
# df_control.polviews=7       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.3157      0.057     -5.517      0.000      -0.428      -0.204
# df_control.marital       -0.1170      0.021     -5.525      0.000      -0.158      -0.075
# =========================================================================================
# """
